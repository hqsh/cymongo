# %%
from cymongo import CyMongoClient

# %%
mongo_uri = 'mongodb://hqs:f@localhost:27017'
client = CyMongoClient(mongo_uri)
collection = client['test']['cymongo_1000_4000']
collection.set_table_info(['date_time', 'blogger_id', 'signature', 'daily_visitor_cnt', 'fan_cnt',
                           'last_logged_date_time', 'heat_degree', 'blog_updated'])
# collection.set_data_frame_info('date_time', 'blogger_id', [
#     'signature', 'daily_visitor_cnt', 'fan_cnt', 'last_logged_date_time', 'heat_degree', 'blog_updated'])
# collection.enable_debug()

# %%
df = collection.find()
df
# Out:
# 28.928148984909058
# -------------- 1 4
# -------------- 2 11
# 28.930885076522827
# 30.98201298713684
# (4000000, 8)
#        date_time blogger_id signature  daily_visitor_cnt      fan_cnt  \
# 0  1262304000000          1     这家伙很懒              34755  20061119897
# 1  1262304000000          2       666              89158  87746325865
# 2  1262304000000          3     这家伙很懒               9360  31404653275
# 3  1262304000000          4     这家伙很懒              81738  24956079265
# 4  1262304000000          5     这家伙很懒              67770  47111596516
#
#    last_logged_date_time  heat_degree  blog_updated
# 0          1261612800000        12.04         False
# 1          1262217600000        72.55          True
# 2          1261958400000        55.28          True
# 3          1261526400000        78.15          True
# 4          1262131200000        68.24          True
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
# ...

# %%
dfs['signature'].head(5)

# %%
dfs['daily_visitor_cnt'].head(5)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>blogger_id</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1262304000000</th>
#       <td>1000</td>
#       <td>2000</td>
#       <td>3000</td>
#       <td>4000</td>
#       <td>5000</td>
#     </tr>
#     <tr>
#       <th>1262390400000</th>
#       <td>1000</td>
#       <td>2000</td>
#       <td>3000</td>
#       <td>4000</td>
#       <td>5000</td>
#     </tr>
#     <tr>
# ...

# %%
dfs['fan_cnt'].head(5)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>blogger_id</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1262304000000</th>
#       <td>100000000000</td>
#       <td>200000000000</td>
#       <td>300000000000</td>
#       <td>400000000000</td>
#       <td>500000000000</td>
#     </tr>
#     <tr>
#       <th>1262390400000</th>
#       <td>100000000000</td>
#       <td>200000000000</td>
#       <td>300000000000</td>
# ...

# %%
dfs['last_logged_date_time'].head(5)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>blogger_id</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1262304000000</th>
#       <td>1262304000000</td>
#       <td>1262304000000</td>
#       <td>1262304000000</td>
#       <td>1262304000000</td>
#       <td>1262304000000</td>
#     </tr>
#     <tr>
#       <th>1262390400000</th>
#       <td>1262390400000</td>
#       <td>1262390400000</td>
#       <td>1262390400000</td>
# ...

# %%
dfs['heat_degree'].head(5)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>blogger_id</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1262304000000</th>
#       <td>100.0</td>
#       <td>200.0</td>
#       <td>300.0</td>
#       <td>400.0</td>
#       <td>500.0</td>
#     </tr>
#     <tr>
#       <th>1262390400000</th>
#       <td>100.0</td>
#       <td>200.0</td>
#       <td>300.0</td>
#       <td>400.0</td>
#       <td>500.0</td>
#     </tr>
#     <tr>
# ...

# %%
dfs['blog_updated'].head(5)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>blogger_id</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1262304000000</th>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1262390400000</th>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
import pandas as pd

# %%
from pymongo import MongoClient
from collections import OrderedDict
import datetime
import random
import pandas as pd
import time

client = MongoClient('mongodb://hqs:f@localhost:27017/test')
db = client['test']
collection = db['cymongo']

cur = collection.find({})

data = {'date_time': [], 'blogger_id': [], 'signature': [], 'daily_visitor_cnt': [], 'fan_cnt': [], 'last_logged_date_time': [], 'heat_degree': [], 'blog_updated': []}

begin = time.time()
for doc in cur:
    for value_name in ['date_time', 'blogger_id', 'signature', 'daily_visitor_cnt', 'fan_cnt', 'last_logged_date_time', 'heat_degree', 'blog_updated']:
        data[value_name].append(doc[value_name])
print(time.time() - begin)

df = pd.DataFrame(data)
print(time.time() - begin)
df2 = df.set_index(['date_time', 'blogger_id'])
print(time.time() - begin)
df3 = df2.unstack('blogger_id')
print(time.time() - begin)
df3
# Out:
# 59.41457390785217
# 65.33463096618652
# 66.68701195716858
# 74.7403039932251
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="10" halign="left">blog_updated</th>
#       <th>...</th>
#       <th colspan="10" halign="left">signature</th>
#     </tr>
#     <tr>
#       <th>blogger_id</th>
#       <th>1</th>
#       <th>10</th>
#       <th>100</th>
#       <th>1000</th>
#       <th>1001</th>
#       <th>1002</th>
#       <th>1003</th>
#       <th>1004</th>
#       <th>1005</th>
#       <th>1006</th>
#       <th>...</th>
#       <th>990</th>
#       <th>991</th>
#       <th>992</th>
#       <th>993</th>
#       <th>994</th>
#       <th>995</th>
#       <th>996</th>
#       <th>997</th>
# ...
